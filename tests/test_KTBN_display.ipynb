# %%
import pyAgrum as gum
import pyAgrum.lib.notebook as gnb
import sys
import os
sys.path.insert(0, os.path.abspath(os.path.join(os.path.curdir, '..', 'lib')))
import KTBN_notebook
from KTBN import KTBN

# %%
# Créer un KTBN simple
ktbn = KTBN(k=2, delimiter='#')

# Ajouter des variables
ktbn.addVariable("A", temporal=True)
ktbn.addVariable("B", temporal=True)
ktbn.addVariable("C", temporal=False)

# Ajouter des arcs
ktbn.addArc(("A", 0), ("B", 0))
ktbn.addArc(("A", 0), ("A", 1))
ktbn.addArc(("C", -1), ("B", 1))

# %%
# Afficher le KTBN
show_ktbn(ktbn)

# %%
# Afficher le KTBN déroulé pour 2 tranches supplémentaires
show_unroll(ktbn, 2)
